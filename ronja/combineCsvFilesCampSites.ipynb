# %%
# Applicable for Monatsbericht Tourismus from 2002-01 to 2005-12 (Sheet 4) converted with excel2csv_Monatsbericht_Tourismus_0201_0512.py

import pandas as pd
import os

def preprocess_df(df):
    df['A'] = df['A'].astype(str)
    df = df.map(lambda x: x.strip() if isinstance(x, str) else x)
    if df.iloc[0]['A'] != 'Baden-Württemberg' or 'Schleswig-Holstein':
        df = df.iloc[1:]
    if df.iloc[-1]['A'] != 'Bundesgebiet insgesamt':
        df = df.iloc[:-1]
    return df

directory = 'C:\\Users\\Ronja\\Documents\\Studium\\Semester 4\\DABI2\\Projekt\\Umsatzdaten\\DESTATIS\\Output\\0201_0512\\4\\'
dataframes = []

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        df = pd.read_csv(os.path.join(directory, filename))
        df = preprocess_df(df)
        dataframes.append(df)

if len(set(len(df) for df in dataframes)) > 1:
    raise ValueError("Not all dataframes have the same length")

all_data = pd.concat(dataframes, ignore_index=True)
rename_map = {'Bundesgebiet insgesamt': 'Gesamt', 'Meckl.-Vorpommern': 'Mecklenburg-Vorpommern', 'Mecklburg-Vorpommern': 'Mecklenburg-Vorpommern', 'Hamburg 5)': 'Hamburg', 'Bundesgebiet 6)': 'Gesamt', 'Bundesgebiet insgesamt 5)': 'Gesamt', 'Bundesgebiet': 'Gesamt'}
all_data['A'] = all_data['A'].replace(rename_map)
all_data.rename(columns={'A': 'Land', 'B': 'campingplaetze_anzahl', 'C': 'urlaubs_campingplaetze_anzahl', 'D': 'urlaubs_campingplaetze_offen', 'E': 'urlaubs_stellplaetze_anzahl', 'F': 'urlaubs_stellplaetze_offen', 'G': 'change_urlaubs_stellplaetze_offen_vorjahresmonat', 'H': 'anteil_urlaubs_stellplaetze_offen_an_urlaubs_stellplaetze_anzahl'}, inplace=True)

short_forms = ['Gesamt', 'Baden-Württemberg', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen', 'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern', 'Niedersachsen', 'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland', 'Sachsen', 'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen']
current_prefix = None

all_data[['jahr', 'monat']] = all_data['Sequence'].astype(str).str.extract(r'(\d{4})(\d{2})')
all_data.drop(columns=['Sequence'], inplace=True)

month_map = {
    '01': 'Januar', '02': 'Februar', '03': 'März', '04': 'April', '05': 'Mai', '06': 'Juni',
    '07': 'Juli', '08': 'August', '09': 'September', '10': 'Oktober', '11': 'November', '12': 'Dezember'
}
all_data['monat'] = all_data['monat'].replace(month_map)

all_data = all_data[['Land', 'jahr', 'monat'] + [col for col in all_data.columns if col not in ['Land', 'jahr', 'monat']]]

all_data = all_data[all_data['Land'] != 'nan']
all_data.fillna('.', inplace=True)

int_columns = ['jahr', 'campingplaetze_anzahl', 'urlaubs_campingplaetze_anzahl', 'urlaubs_campingplaetze_offen', 'urlaubs_stellplaetze_anzahl', 'urlaubs_stellplaetze_offen']
float_columns = ['change_urlaubs_stellplaetze_offen_vorjahresmonat', 'anteil_urlaubs_stellplaetze_offen_an_urlaubs_stellplaetze_anzahl']
all_data[int_columns] = all_data[int_columns].apply(pd.to_numeric, errors='coerce').fillna('.')
all_data[float_columns] = all_data[float_columns].apply(pd.to_numeric, errors='coerce').fillna('.')

all_data.to_csv('C:\\Users\\Ronja\\Documents\\Studium\\Semester 4\\DABI2\\Projekt\\Umsatzdaten\\DESTATIS\\Output\\0201_0512\\stellplaetze_0201_0512.csv', index=False)

# %%
# Applicable for Monatsbericht Tourismus from 2002-01 to 2005-12 (Sheet 4) converted with excel2csv_Monatsbericht_Tourismus_0201_0512.py

import pandas as pd
import os

def preprocess_df(df):
    df['A'] = df['A'].astype(str)
    df = df.map(lambda x: x.strip() if isinstance(x, str) else x)
    if df.iloc[0]['A'] != 'Baden-Württemberg' or 'Schleswig-Holstein':
        df = df.iloc[1:]
    if df.iloc[-1]['A'] != 'Bundesgebiet insgesamt':
        df = df.iloc[:-1]
    return df

directory = 'C:\\Users\\Ronja\\Documents\\Studium\\Semester 4\\DABI2\\Projekt\\Umsatzdaten\\DESTATIS\\Output\\0601_0812\\5\\'
dataframes = []

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        df = pd.read_csv(os.path.join(directory, filename))
        df = preprocess_df(df)
        dataframes.append(df)

if len(set(len(df) for df in dataframes)) > 1:
    raise ValueError("Not all dataframes have the same length")

all_data = pd.concat(dataframes, ignore_index=True)
rename_map = {'Bundesgebiet': 'Gesamt', 'Bundesgebiet ……………': 'Gesamt'}
all_data['A'] = all_data['A'].replace(rename_map)
all_data.rename(columns={'A': 'Land', 'B': 'campingplaetze_anzahl', 'C': 'urlaubs_campingplaetze_anzahl', 'D': 'urlaubs_campingplaetze_offen', 'E': 'urlaubs_stellplaetze_anzahl', 'F': 'urlaubs_stellplaetze_offen', 'G': 'change_urlaubs_stellplaetze_offen_vorjahresmonat', 'H': 'anteil_urlaubs_stellplaetze_offen_an_urlaubs_stellplaetze_anzahl'}, inplace=True)

short_forms = ['Gesamt', 'Baden-Württemberg', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen', 'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern', 'Niedersachsen', 'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland', 'Sachsen', 'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen']
current_prefix = None

all_data[['jahr', 'monat']] = all_data['Sequence'].astype(str).str.extract(r'(\d{4})(\d{2})')
all_data.drop(columns=['Sequence'], inplace=True)

month_map = {
    '01': 'Januar', '02': 'Februar', '03': 'März', '04': 'April', '05': 'Mai', '06': 'Juni',
    '07': 'Juli', '08': 'August', '09': 'September', '10': 'Oktober', '11': 'November', '12': 'Dezember'
}
all_data['monat'] = all_data['monat'].replace(month_map)

all_data = all_data[['Land', 'jahr', 'monat'] + [col for col in all_data.columns if col not in ['Land', 'jahr', 'monat']]]

all_data = all_data[all_data['Land'] != 'nan']

int_columns = ['jahr', 'campingplaetze_anzahl', 'urlaubs_campingplaetze_anzahl', 'urlaubs_campingplaetze_offen', 'urlaubs_stellplaetze_anzahl', 'urlaubs_stellplaetze_offen']
float_columns = ['change_urlaubs_stellplaetze_offen_vorjahresmonat', 'anteil_urlaubs_stellplaetze_offen_an_urlaubs_stellplaetze_anzahl']
all_data[int_columns] = all_data[int_columns].apply(pd.to_numeric, errors='coerce').fillna('.')
all_data[float_columns] = all_data[float_columns].apply(pd.to_numeric, errors='coerce').fillna('.')

all_data.to_csv('C:\\Users\\Ronja\\Documents\\Studium\\Semester 4\\DABI2\\Projekt\\Umsatzdaten\\DESTATIS\\Output\\0601_0812\\stellplaetze_0601_0812.csv', index=False)

# %%
all_data
# Out:
#                        Land  jahr     monat campingplaetze_anzahl  \
# 0        Schleswig-Holstein  2006    Januar                 274.0
# 1                   Hamburg  2006    Januar                     .
# 2             Niedersachsen  2006    Januar                 326.0
# 3                    Bremen  2006    Januar                     .
# 4       Nordrhein-Westfalen  2006    Januar                 208.0
# ..                      ...   ...       ...                   ...
# 642  Mecklenburg-Vorpommern  2008  Dezember                 188.0
# 643                 Sachsen  2008  Dezember                 108.0
# 644          Sachsen-Anhalt  2008  Dezember                  72.0
# 645               Thüringen  2008  Dezember                  60.0
# 647                  Gesamt  2008  Dezember                2861.0
#
#     urlaubs_campingplaetze_anzahl urlaubs_campingplaetze_offen  \
# 0                           272.0                         26.0
# ...

# %%
# Applicable for Monatsbericht Tourismus from 2002-01 to 2005-12 (Sheet 3.1) converted with excel2csv_Monatsbericht_Tourismus_0201_0512.py
# Applicable for Monatsbericht Tourismus from 2002-01 to 2005-12 (Sheet 4) converted with excel2csv_Monatsbericht_Tourismus_0201_0512.py

import pandas as pd
import os

def preprocess_df(df):
    df['A'] = df['A'].astype(str)
    df = df.map(lambda x: x.strip() if isinstance(x, str) else x)
    if df.iloc[0]['A'] != 'Deutschland':
        df = df.iloc[1:]
    if df.iloc[-1]['A'] != 'Thüringen':
        df = df.iloc[:-1]
    return df

directory = 'C:\\Users\\Ronja\\Documents\\Studium\\Semester 4\\DABI2\\Projekt\\Umsatzdaten\\DESTATIS\\Output\\0901_2212\\2.4\\'
dataframes = []

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        df = pd.read_csv(os.path.join(directory, filename))
        df = preprocess_df(df)
        dataframes.append(df)

if len(set(len(df) for df in dataframes)) > 1:
    raise ValueError("Not all dataframes have the same length")

all_data = pd.concat(dataframes, ignore_index=True)
rename_map = {'Bundesgebiet insgesamt': 'Gesamt', 'Meckl.-Vorpommern': 'Mecklenburg-Vorpommern', 'Mecklburg-Vorpommern': 'Mecklenburg-Vorpommern', 'Hamburg 5)': 'Hamburg', 'Bundesgebiet 6)': 'Gesamt', 'Bundesgebiet insgesamt 5)': 'Gesamt', 'Bundesgebiet': 'Gesamt'}
all_data['A'] = all_data['A'].replace(rename_map)
all_data.rename(columns={'A': 'Land', 'B': 'campingplaetze_anzahl', 'C': 'urlaubs_campingplaetze_anzahl', 'D': 'urlaubs_campingplaetze_offen', 'E': 'urlaubs_stellplaetze_anzahl', 'F': 'urlaubs_stellplaetze_offen', 'G': 'change_urlaubs_stellplaetze_offen_vorjahresmonat', 'H': 'anteil_urlaubs_stellplaetze_offen_an_urlaubs_stellplaetze_anzahl'}, inplace=True)

short_forms = ['Gesamt', 'Baden-Württemberg', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen', 'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern', 'Niedersachsen', 'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland', 'Sachsen', 'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen']
current_prefix = None

all_data[['jahr', 'monat']] = all_data['Sequence'].astype(str).str.extract(r'(\d{4})(\d{2})')
all_data.drop(columns=['Sequence'], inplace=True)

month_map = {
    '01': 'Januar', '02': 'Februar', '03': 'März', '04': 'April', '05': 'Mai', '06': 'Juni',
    '07': 'Juli', '08': 'August', '09': 'September', '10': 'Oktober', '11': 'November', '12': 'Dezember'
}
all_data['monat'] = all_data['monat'].replace(month_map)

all_data = all_data[['Land', 'jahr', 'monat'] + [col for col in all_data.columns if col not in ['Land', 'jahr', 'monat']]]

all_data = all_data[all_data['Land'] != 'nan']
all_data.fillna('.', inplace=True)

int_columns = ['jahr', 'campingplaetze_anzahl', 'urlaubs_campingplaetze_anzahl', 'urlaubs_campingplaetze_offen', 'urlaubs_stellplaetze_anzahl', 'urlaubs_stellplaetze_offen']
float_columns = ['change_urlaubs_stellplaetze_offen_vorjahresmonat', 'anteil_urlaubs_stellplaetze_offen_an_urlaubs_stellplaetze_anzahl']
all_data[int_columns] = all_data[int_columns].apply(pd.to_numeric, errors='coerce').fillna('.')
all_data[float_columns] = all_data[float_columns].apply(pd.to_numeric, errors='coerce').fillna('.')

all_data.to_csv('C:\\Users\\Ronja\\Documents\\Studium\\Semester 4\\DABI2\\Projekt\\Umsatzdaten\\DESTATIS\\Output\\0901_2212\\stellplaetze_0901_2212.csv', index=False)

# %%
all_data
# Out:
#                     Land  jahr     monat  campingplaetze_anzahl  \
# 0            Deutschland  2009    Januar                 2838.0
# 1      Baden-Württemberg  2009    Januar                  325.0
# 2                 Bayern  2009    Januar                  432.0
# 3                 Berlin  2009    Januar                    8.0
# 4            Brandenburg  2009    Januar                  175.0
# ...                  ...   ...       ...                    ...
# 2834            Saarland  2022  Dezember                   32.0
# 2835             Sachsen  2022  Dezember                  108.0
# 2836      Sachsen-Anhalt  2022  Dezember                   88.0
# 2837  Schleswig-Holstein  2022  Dezember                  278.0
# 2838           Thüringen  2022  Dezember                   93.0
#
#       urlaubs_campingplaetze_anzahl  urlaubs_campingplaetze_offen  \
# 0                            1217.0                          11.7
# ...

# %%
dataframes_lengths = {}

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        df = pd.read_csv(os.path.join(directory, filename))
        df = preprocess_df(df)
        dataframes.append(df)
        dataframes_lengths[filename] = len(df)

print(dataframes_lengths)
# Out:
# {'MonatsberichtTourismus_0901.csv': 17, 'MonatsberichtTourismus_0902.csv': 17, 'MonatsberichtTourismus_0903.csv': 17, 'MonatsberichtTourismus_0904.csv': 17, 'MonatsberichtTourismus_0905.csv': 17, 'MonatsberichtTourismus_0906.csv': 17, 'MonatsberichtTourismus_0907.csv': 17, 'MonatsberichtTourismus_0908.csv': 17, 'MonatsberichtTourismus_0909.csv': 17, 'MonatsberichtTourismus_0910.csv': 17, 'MonatsberichtTourismus_0911.csv': 17, 'MonatsberichtTourismus_0912.csv': 17, 'MonatsberichtTourismus_1001.csv': 17, 'MonatsberichtTourismus_1002.csv': 17, 'MonatsberichtTourismus_1003.csv': 17, 'MonatsberichtTourismus_1004.csv': 17, 'MonatsberichtTourismus_1005.csv': 17, 'MonatsberichtTourismus_1006.csv': 17, 'MonatsberichtTourismus_1007.csv': 17, 'MonatsberichtTourismus_1008.csv': 17, 'MonatsberichtTourismus_1009.csv': 17, 'MonatsberichtTourismus_1010.csv': 17, 'MonatsberichtTourismus_1011.csv': 17, 'MonatsberichtTourismus_1012.csv': 17, 'MonatsberichtTourismus_1101.csv': 17, 'MonatsberichtTourismu
# ...
