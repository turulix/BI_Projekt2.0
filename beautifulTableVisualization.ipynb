# %%
import pandas as pl
from os import getenv
from sqlalchemy import create_engine
import polars.selectors as cs
from great_tables import GT, loc, style
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# Define database connection parameters
username = getenv('DB_USER').lower()
password = getenv('DB_PASSWORD')
host = getenv('DB_HOST')
port = getenv('DB_PORT')
database = getenv('DB_NAME')

# Define the connection string
# Format: dialect+driver://username:password@host:port/database
connection_string = f'postgresql://{username}:{password}@{host}:{port}/{database}'

# Create the engine
engine = create_engine(connection_string)
# Import the data to separate dataframes
df_main = pl.read_sql("SELECT * FROM original_data.super_duper_table_of_doom", engine)

# %%
df_main
# Out:
#                    land        date  ankuenfte_anzahl  \
# 0     Baden-Württemberg  2024-03-01           78875.0
# 1                Bayern  2024-03-01          111365.0
# 2                Berlin  2024-03-01            1457.0
# 3           Brandenburg  2024-03-01           12123.0
# 4                Bremen  2024-03-01            6883.0
# ...                 ...         ...               ...
# 4250            Hamburg  2022-11-01            3367.0
# 4251             Bremen  2022-12-01            3606.0
# 4252            Hamburg  2022-12-01            2615.0
# 4253           Saarland  2022-12-01             720.0
# 4254            Sachsen  2022-12-01            1802.0
#
#       ankuenfte_veraenderung_zum_vorjahreszeitraum_prozent  \
# 0                                                 105.8
# 1                                                 160.6
# 2                                                  90.5
# 3                                                 193.5
# 4                                                 108.3
# ...                                                 ...
# 4250                                               33.0
# 4251                                                NaN
# 4252                                                NaN
# 4253                                                NaN
# 4254                                                NaN
#
#       uebernachtungen_anzahl  \
# 0                   219418.0
# 1                   307709.0
# 2                     5734.0
# 3                    34061.0
# 4                    12945.0
# ...                      ...
# 4250                     NaN
# 4251                  7746.0
# 4252                  3516.0
# 4253                  1359.0
# 4254                  5883.0
#
#       uebernachtungen_veraenderung_zum_vorjahreszeitraum_prozent  \
# 0                                                 132.4
# 1                                                 161.7
# 2                                                 117.1
# 3                                                 281.4
# 4                                                  89.5
# ...                                                 ...
# 4250                                                NaN
# 4251                                                NaN
# 4252                                                NaN
# 4253                                                NaN
# 4254                                                NaN
#
#       durchsch_aufenthaltsdauer_tage  mean_air_temp_max  mean_air_temp_mean  \
# 0                                2.8          12.374740            7.372771
# 1                                2.8          12.545220            7.136138
# 2                                3.9          13.168390            8.178442
# 3                                2.8          12.799730            7.691393
# 4                                1.9          11.955060            8.040822
# ...                              ...                ...                 ...
# 4250                             NaN           9.443800            6.886927
# 4251                             2.1           5.064556            2.522151
# 4252                             1.3           4.688140            2.289622
# 4253                             1.9           5.341605            3.027890
# 4254                             3.3           3.742183            1.443099
#
#       mean_air_temp_min  ...  std_soil_moist  std_soil_temperature_5cm  \
# 0              2.708467  ...         3.03137                  1.095861
# 1              2.099823  ...        3.638682                 0.8525879
# 2              3.079458  ...        0.115587                 0.0794624
# 3              2.461740  ...        0.760745                 0.3207129
# 4              4.297468  ...        0.397123                 0.0613891
# ...                 ...  ...             ...                       ...
# 4250           3.879514  ...             0.0                 0.0845322
# 4251          -0.217405  ...        1.407978                 0.0707927
# 4252          -0.396495  ...        1.851014                 0.0640182
# 4253           0.616942  ...         0.68653                 0.2909778
# 4254          -1.209170  ...        8.939608                 0.1913168
#
#       std_sunshine_duration  campingplaetze_anzahl  \
# 0                  5.038108                   None
# 1                  7.238923                   None
# 2                  7.108747                   None
# 3                  7.685427                   None
# 4                  0.499358                   None
# ...                     ...                    ...
# 4250               2.308657                    7.0
# 4251               1.547215                    3.0
# 4252               0.657893                    7.0
# 4253               2.960537                   32.0
# 4254               4.207757                  108.0
#
#       urlaubs_campingplaetze_anzahl  urlaubs_campingplaetze_offen  \
# 0                              None                          None
# 1                              None                          None
# 2                              None                          None
# 3                              None                          None
# 4                              None                          None
# ...                             ...                           ...
# 4250                            3.0                         -25.0
# 4251                            3.0                           0.0
# 4252                            3.0                         -25.0
# 4253                           14.0                           7.0
# 4254                           36.0                          89.0
#
#       urlaubs_stellplaetze_anzahl  urlaubs_stellplaetze_offen  \
# 0                            None                        None
# 1                            None                        None
# 2                            None                        None
# 3                            None                        None
# 4                            None                        None
# ...                           ...                         ...
# 4250                        215.0                       -12.0
# 4251                        316.0                         0.0
# 4252                        215.0                        None
# 4253                       1089.0                        67.0
# 4254                       2306.0                        84.0
#
#       change_urlaubs_stellplaetze_offen_vorjahresmonat  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ...                                                ...
# 4250                                             506.0
# 4251                                             316.0
# 4252                                             506.0
# 4253                                            2146.0
# 4254                                            6603.0
#
#       anteil_urlaubs_stellplaetze_offen_an_urlaubs_stellplaetze_anzah
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 4250                                               42.5
# 4251                                              100.0
# 4252                                               42.5
# 4253                                               50.7
# 4254                                               34.9
#
# [4255 rows x 36 columns]

# %%
sel_rev = cs.starts_with("revenue")
sel_prof = cs.starts_with("profit")

# yo

coffee_table = (
    GT(coffee_sales)
    .tab_header("Sales of Coffee Equipment")
    .tab_spanner(label="Revenue", columns=sel_rev)
    .tab_spanner(label="Profit", columns=sel_prof)
    .cols_label(
        revenue_dollars="Amount",
        profit_dollars="Amount",
        revenue_pct="Percent",
        profit_pct="Percent",
        monthly_sales="Monthly Sales",
        icon="",
        product="Product",
    )
    .fmt_nanoplot("monthly_sales", plot_type="bar")
    .fmt_image("icon", path="_data/coffee-table-icons/")
    .sub_missing(missing_text="")
)

coffee_table
